# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
import torch.nn.functional as F
import numpy as np
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR,MultiStepLR
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data import DataLoader, Dataset, TensorDataset
import torchvision
from pylab import *
from dataclasses import dataclass
import math
import matplotlib as mpl
from datetime import date
import dill

today = date.today()
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"  #  Specify which GPUs should be visible and available to PyTorch

# %%
# whether to generate new dataset or load an existing one
LOAD_DATASET = True

# %%
# into the spiking MLP after each time step
criterion = nn.CrossEntropyLoss();  # because it is a classification

# %% [markdown]
# # Quantization F

# %%
from collections import namedtuple
import torch
import torch.nn as nn
import math

QTensor = namedtuple('QTensor', ['tensor', 'scale', 'zero_point'])

def calcScaleZeroPoint(min_val, max_val,num_bits=8):
  # Calc Scale and zero point of next
  qmin = 0.
  qmax = 2.**num_bits - 1.

  scale = (max_val - min_val) / (qmax - qmin)

  initial_zero_point = qmin - min_val / scale

  zero_point = 0
  if initial_zero_point < qmin:
      zero_point = qmin
  elif initial_zero_point > qmax:
      zero_point = qmax
  else:
      zero_point = initial_zero_point

  zero_point = int(zero_point)

  return scale, zero_point

def calcScaleZeroPointSym(min_val, max_val,num_bits=8):

  # Calc Scale
  max_val = max(abs(min_val), abs(max_val))
  qmin = 0.
  qmax = 2.**(num_bits-1) - 1.

  scale = max_val / qmax

  return scale, 0

def quantize_tensor(x, num_bits=8, min_val=None, max_val=None):

    if not min_val and not max_val:
      min_val, max_val = x.min(), x.max()

    qmin = 0.
    qmax = 2.**num_bits - 1.

    scale, zero_point = calcScaleZeroPoint(min_val, max_val, num_bits)
    q_x = zero_point + x / scale
    q_x.clamp_(qmin, qmax).round_()
    q_x = q_x.round().byte()

    return QTensor(tensor=q_x, scale=scale, zero_point=zero_point)

def dequantize_tensor(q_x):
    return q_x.scale * (q_x.tensor.float() - q_x.zero_point)

# num_bits=4 means 3 bits for positive and negative side respectively
def quantize_tensor_sym(x, num_bits=4, min_val=None, max_val=None):

    if not min_val and not max_val or x.max() <= max_val * 0.9:
      min_val, max_val = x.min(), x.max()

    max_val = max(abs(min_val), abs(max_val))
    qmin = 0.
    qmax = 2.**(num_bits-1) - 1.

    scale = max_val / qmax

    q_x = x/scale

    q_x.clamp_(-qmax, qmax).round_()
    q_x = q_x.round()
    return QTensor(tensor=q_x, scale=scale, zero_point=0)

def dequantize_tensor_sym(q_x):
    return q_x.scale * (q_x.tensor.float())

def exp_scaler(n_bits, a, b, c, max_val):
    x_max = (math.log(max_val / a) - c) / b
    unit_x = x_max / (2. ** n_bits - 1)
    x_ticks = torch.tensor([unit_x * item for item in range(1, int(2. ** n_bits))])
    y_ticks = a * torch.exp(b * x_ticks + c)

    y_range = torch.zeros(len(y_ticks)) 

    # Ensure y_range has the correct size
    y_range[1:] = (y_ticks[:-1] + y_ticks[1:]) / 2  # Midpoints
    y_range[0] = y_ticks[0] / 2  # Lower bound
    return y_range, y_ticks

def exp_quantizer(x, n_bits, max_val, a, b, c):
    device = x.device
    y_range, y_ticks = exp_scaler(n_bits, a, b, c, max_val)

    y_range = y_range.to(device)
    y_ticks = y_ticks.to(device)
    
    abs_x = torch.abs(x)
    sign = torch.sign(x)

    # Find bin index where abs_x falls in y_range
    idx = torch.searchsorted(y_range, abs_x) - 1  # Find the index in y_range
    idx = torch.clamp(idx, 0, len(y_ticks) - 1)  # Ensure valid index

    # Assign quantized values
    q_x = torch.where(abs_x < y_range[0], torch.tensor(0.0, device=x.device), y_ticks[idx])
    return q_x * sign  # Restore the sign to the output

def exp_quantizer_probabilistic(x, n_bits, max_val, a, b, c, base_temp=0.02, scale_factor=0.5):
    device = x.device
    y_range, y_ticks = exp_scaler(n_bits, a, b, c, max_val)

    y_range = y_range.to(device)
    y_ticks = y_ticks.to(device)

    abs_x = torch.abs(x)
    sign = torch.sign(x)

    # **Prepend 0 to y_ticks**
    y_ticks = torch.cat([torch.tensor([0.0], device=device), y_ticks])

    # **Normalize y_ticks by its max value**
    max_y_ticks = y_ticks.max()
    normalized_y_ticks = y_ticks / max_y_ticks  # Now in range [0, 1]

    # **Adaptive temperature based on normalized y_ticks**
    adaptive_temperature = base_temp * (scale_factor + normalized_y_ticks)

    # Compute distances between abs_x and each y_tick
    distances = torch.abs(abs_x.unsqueeze(-1) - y_ticks)  # Shape: [batch_size, num_ticks]

    # Convert distances to probabilities using the adaptive temperature
    probs = torch.exp(-distances / adaptive_temperature)  # Exponential decay
    probs = probs / probs.sum(dim=-1, keepdim=True)  # Normalize

    # Sample from the probability distribution
    idx = torch.multinomial(probs, 1).squeeze(-1)  # Get sampled indices

    # Assign quantized values
    q_x = y_ticks[idx]

    return q_x * sign  # Restore sign

class FakeQuantOp_exp_probabilistic(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x, base_temp, scale_factor, num_bits=3, min_val=None, max_val=None):
        x = exp_quantizer_probabilistic(x, num_bits, max_val, a=0.01, b=0.5, c=0, base_temp=base_temp, scale_factor=scale_factor)
        return x

    @staticmethod
    def backward(ctx, grad_output):
        # straight through estimator
        return grad_output, None, None, None

class FakeQuantOp_exp(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x, num_bits=3, min_val=None, max_val=None):
        x = exp_quantizer(x, num_bits, max_val, a=0.01, b=0.5, c=0)
        return x

    @staticmethod
    def backward(ctx, grad_output):
        # straight through estimator
        return grad_output, None, None, None
    
class FakeQuantOp(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x, num_bits=3, min_val=None, max_val=None):
        x = quantize_tensor_sym(x, num_bits=num_bits, min_val=min_val, max_val=max_val)
        x = dequantize_tensor_sym(x)
        return x

    @staticmethod
    def backward(ctx, grad_output):
        # straight through estimator
        return grad_output, None, None, None

# %% [markdown]
# # Neuron MODEL

# %%
def gaussian(x, mu=0., sigma=.5):
    return torch.exp(-((x - mu) ** 2) / (2 * sigma ** 2)) / torch.sqrt(2 * torch.tensor(math.pi)) / sigma

class ActFun(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input):  # input = membrane potential- threshold
        ctx.save_for_backward(input)
        return input.gt(0).float()  # is firing ???

    @staticmethod
    def backward(ctx, grad_output):  # approximate the gradients
        input, = ctx.saved_tensors
        grad_input = grad_output.clone()
        # temp = abs(input) < lens
        scale = 15.0
        hight = .15
        #temp = torch.exp(-(input**2)/(2*lens**2))/torch.sqrt(2*torch.tensor(math.pi))/lens
        temp = gaussian(input, mu=0., sigma=lens) * (1. + hight) \
                - gaussian(input, mu=lens, sigma=scale * lens) * hight \
                - gaussian(input, mu=-lens, sigma=scale * lens) * hight
        #print("gamma in ActFun:backward", gamma)
        return grad_input * temp.float() * gamma

act_fun = ActFun.apply

### NEURON MODEL
def mem_update_adp(x, mem, thr):
    # raise Exception
    mem = decay_neu * mem + x
    inputs_ = mem - thr
    spike = act_fun(inputs_)  # (inputs_ > 0).float()
    mem = mem * (1 - spike)
    negative_ = (mem < 0).float()  # Check all the negative elements of mem and convert into floating number (1.0 or 0.0)
    mem = (mem * (1 - negative_)) - (0 * negative_)
    return mem, spike

# %% [markdown]
# # mlpsnn Def

# %%
class mlpsnn(nn.Module):
    def __init__(self, n_inputs, hidden_dim, n_outputs):
        super(mlpsnn, self).__init__()

        self.n_inputs = n_inputs
        self.hidden_size = hidden_dim
        self.output_size = n_outputs

        # nn is from torch library
        self.i2h = nn.Linear(self.n_inputs, self.hidden_size, bias=False)
        self.h2o = nn.Linear(self.hidden_size, self.output_size, bias=False)

        self.thr_i = nn.Parameter(torch.Tensor(self.n_inputs))  # , requires_grad=True) #learn threshold
        self.thr_h = nn.Parameter(torch.Tensor(self.hidden_size))  # , requires_grad=True) #learn threshold
        self.thr_o = nn.Parameter(torch.Tensor(self.output_size))  # , requires_grad=True) #learn threshold

        nn.init.xavier_uniform_(self.i2h.weight)
        nn.init.xavier_uniform_(self.h2o.weight)

        nn.init.constant_(self.thr_h, 1.0)
        nn.init.constant_(self.thr_o, 1.0)
        nn.init.constant_(self.thr_i, 1.0)

    def forward(self, input):
        # init
        input_mem = torch.zeros(self.n_inputs)
        hidden_mem =  torch.zeros(self.hidden_size)
        output_mem =  torch.zeros(self.output_size)
        hidden_spike = torch.zeros(self.hidden_size)
        output_spike = torch.zeros(self.output_size)

        # Keep track on the spike train of each layer
        input_spike_train = []
        hidden_spike_train = []
        output_spike_train = []

        # Feed in the whole sequence
        batch_size, seq_num, input_dimx, input_dimy = input.shape

        loss_h = Variable(torch.Tensor([0]), requires_grad=True)

        output_ = []
        I_h = []
        predictions = []

        output_spike_sum = torch.zeros(batch_size, self.output_size).to(device)

        for this_t in range(input_dimy):

            #input organization
            input_x = torch.zeros([batch_size, input_dimx])
            input_x = input[:, 0, :, ((this_t)% input_dimy)]

            #################   update states  #########################
            input_mem, i_input = mem_update_adp(input_x.to(device), input_mem.to(device), self.thr_i)                                      # The first layer neuron only does activation.....
            input_spike_train.append(i_input.detach().cpu().view(1, -1))
            h_input = self.i2h(i_input.float())
            hidden_mem, hidden_spike = mem_update_adp(h_input.to(device),hidden_mem.to(device), self.thr_h)
            hidden_spike_train.append(hidden_spike.detach().cpu().view(1, -1))

            output_inputs = self.h2o(hidden_spike.to(device))
            output_mem, output_spike = mem_update_adp(output_inputs.to(device), output_mem.to(device), self.thr_o)
            output_spike_train.append(output_spike.detach().cpu().view(1, -1))

            output_spike_sum[:, :] = output_spike_sum[:, :].to(device) + output_spike.to(device)

        input_spike_train = torch.cat(input_spike_train, dim=0)
        hidden_spike_train = torch.cat(hidden_spike_train, dim=0)
        output_spike_train = torch.cat(output_spike_train, dim=0)

        #################   return spikes sum  #########################
        return output_spike_sum     #, input_spike_train, hidden_spike_train, output_spike_train

# %% [markdown]
# # lr scaling (for exp quantization)

# %%
import torch
import torch.optim as optim
import torch.nn as nn

def adjusted_sigmoid(x, x_target=0.6):
    # Solve for s to ensure sigmoid(x_target) = 0.95
    center = x_target / 2
    s = -torch.log(torch.tensor(1/0.95 - 1)) / (x_target - center)
    return 1 / (1 + torch.exp(-s * (torch.abs(x) - center)))

def cal_lr(x, max_val, min_lr=0.01, max_lr=0.5):
    return min_lr + (max_lr - min_lr) * adjusted_sigmoid(x, x_target=max_val)

def pre_update(model, max_val, min, max):
    for i, param in enumerate(model.parameters()):
        if i >= 2:
            lr_matrice = cal_lr(param, max_val, min_lr=min, max_lr=max)
            param.grad.mul_(lr_matrice) 
            #print(f'param is : {param}')
            #print(f'Learning rate is : {lr_matrice}')
            #print(f'new_matrice gradient is : {param.grad}')

# %% [markdown]
# # Normalizing initial weight matrices

# %%
def normalize_tensor_safe(tensor, min_val, max_val, epsilon=1e-6):
    X_min, X_max = tensor.min(), tensor.max()
    return min_val + (tensor - X_min) * (max_val - min_val) / (X_max - X_min + epsilon)

# %% [markdown]
# # Train/Testing F

# %%
def test1(config, model, test_loader, odorant_idx):
    test_acc = []
    for i, (traces, labels) in enumerate(test_loader):
        batch_size = traces.shape[0]
        traces = traces * -1 * config['amp']
        traces = traces.unsqueeze(1)
        #examples = enumerate(test_loader)
        #batch_idx, (x_emp, y_emp) = next(examples)
        traces = torch.tensor(traces).to(device)#view((-1, x_emp.shape[0], input_dim)).requires_grad_().to(device)
#         traces = traces.clone().detach().to(device)
#         traces = traces.clone().detach().requires_grad_(True).to(device)
        labels = labels[:, 1]
        labels = [odorant_idx.index(element) for element in labels]
        labels = torch.tensor(labels)
        labels = labels.view((-1,batch_size)).long().to(device)

        #print("Testing model")
        output_spike_sum = model.forward(traces)

        #################   classification  #########################
        output_sumspike = F.log_softmax(output_spike_sum, dim=1)
        pred_ = output_sumspike.argmax(axis=1)

        test_accuracy = (pred_.to(device) == labels.to(device)).sum().data.cpu().numpy() / float(len(pred_))

        #print('Test Acc: {:.4f}'.format(test_accuracy))
        test_acc.append(test_accuracy)
    #print('Test Accuracy final: {:.4f}'.format(np.mean(test_acc)))
    return np.mean(test_acc)

# %%
# into the spiking MLP after each time step
criterion =nn.CrossEntropyLoss()

def train_test_val(config, model, train_loader, test_loader, val_loader, odorant_idx, optimizer, min_val, max_val, num_epochs, criterion = criterion, n_bits = 4, gamma=0.8, min_lr=0.01, max_lr=0.5, base_temp=0.02, scale_factor=0.5):
    w_tracker = []
    w_tracker_q = []
    acc_train = [0.] * num_epochs

    if config['use_scheduler']:
        scheduler = StepLR(optimizer, step_size=2, gamma=gamma)
        
    test_acc = []
    val_acc = []
    for epoch in range(num_epochs):
        train_acc = 0.0
        train_loss_sum = 0.0
        predictions = []
        data_size = 0
        temp_test = 0
        if epoch == 0:
            temp_val = test1(config, model, val_loader, odorant_idx)
            print(f'Validation acc before training: {temp_val}')
            val_acc.append(temp_val)
            temp_test = test1(config, model, test_loader, odorant_idx)
            print(f'Test acc before training: {temp_test}')
            test_acc.append(temp_test)
        
        for i, (traces, labels) in enumerate(train_loader):
            batch_size = traces.shape[0]
            data_size = data_size + batch_size
            traces = traces * -1 * config['amp']
            traces = traces.unsqueeze(1)
            traces = traces.to(device)
            labels = labels[:, 1]
            labels = [odorant_idx.index(element) for element in labels]
            labels = torch.tensor(labels)
            labels = labels.view((-1,batch_size)).long().to(device)

            # Clear gradients w.r.t. parameters
            optimizer.zero_grad()
            w_tracker.append(torch.cat([model.i2h.weight.data.flatten(), model.h2o.weight.data.flatten()]).tolist())

            if config['use_quantization']:
                i2h_weight = model.i2h.weight.data
                h2o_weight = model.h2o.weight.data

                # Stack both weight tensors along a new dimension
                stacked_weights = torch.cat([model.i2h.weight.data.flatten(), model.h2o.weight.data.flatten()])

                # Quantize them together
                if config['quantization_type'] == "exponential":
                    quantized_weights = FakeQuantOp_exp_probabilistic.apply(stacked_weights, base_temp, scale_factor, n_bits, min_val, max_val)
                if config['quantization_type'] == "linear":
                    quantized_weights = FakeQuantOp.apply(stacked_weights, n_bits, min_val, max_val)

                # Split them back
                model.i2h.weight.data = quantized_weights[:i2h_weight.numel()].reshape(i2h_weight.shape)
                model.h2o.weight.data = quantized_weights[i2h_weight.numel():].reshape(h2o_weight.shape)

            w_tracker_q.append(torch.cat([model.i2h.weight.data.flatten(), model.h2o.weight.data.flatten()]).tolist())

            output_spike_sum = model.forward(traces) # binary input spikes        

            #################   classification  #########################
            output_sumspike = output_spike_sum #F.log_softmax(output_spike_sum, dim=1)
            pred_ = output_sumspike.argmax(axis=1)
            predictions.append(pred_.data.cpu().numpy())
            loss_h = criterion(output_sumspike.to(device), labels[0].to(device))

            # Getting gradients w.r.t. parameters
            loss_h.sum().backward()         #retain_graph=True
            train_loss_sum += loss_h.detach().cpu().numpy()

            # Manually update parameters
            # pre_update(model, max_val, min=min_lr, max=max_lr)           
            optimizer.step()
            predicted = pred_.t()
            train_acc += (predicted == labels).sum()
        
        if config['use_quantization']:
            # Stack both weight tensors along a new dimension
            stacked_weights = torch.cat([model.i2h.weight.data.flatten(), model.h2o.weight.data.flatten()])
            # Quantize them together
            if config['quantization_type'] == "exponential":
                quantized_weights = FakeQuantOp_exp_probabilistic.apply(stacked_weights, base_temp, scale_factor, n_bits, min_val, max_val)
            if config['quantization_type'] == "linear":
                quantized_weights = FakeQuantOp.apply(stacked_weights, n_bits, min_val, max_val)
            # Split them back
            model.i2h.weight.data = quantized_weights[:i2h_weight.numel()].reshape(i2h_weight.shape)
            model.h2o.weight.data = quantized_weights[i2h_weight.numel():].reshape(h2o_weight.shape)

        temp_val = test1(config, model, val_loader, odorant_idx)
        val_acc.append(temp_val)
        temp_test = test1(config, model, test_loader, odorant_idx)
        test_acc.append(temp_test)

        train_acc_np = train_acc.data.cpu().numpy()
        acc_train[epoch] = train_acc_np/data_size
        if config['use_scheduler']:
            scheduler.step()
        print('epoch: {:3d}, Train Loss: {:.4f}, Train Acc: {:.4f}, Current val_accuracy: {:.4f}, Current test_accuracy: {:.4f}'.format(epoch,
                                                                           train_loss_sum.item()/data_size,
                                                                           train_acc_np/data_size,
                                                                           temp_val,
                                                                           temp_test))
    return test_acc[val_acc.index(max(val_acc[4:]), 4)], w_tracker, w_tracker_q

# %% [markdown]
# # Generate Dataset

# %%
import os
import shutil
import subprocess
import sys
import dill
import json

# Define number of datasets and the folders for each group
num_datasets = 12
groups = {
    "group1": range(0, 4),
    "group2": range(4, 8),
    "group3": range(8, 12)
}

# Directory where the datasets are saved
saved_datasets_dir = "saved_datasets/"

# Path to the new directories for groups
group_dirs = {group: os.path.join(saved_datasets_dir, group) for group in groups}

# Create group directories if they don't exist
for group_dir in group_dirs.values():
    if not os.path.exists(group_dir):
        os.makedirs(group_dir)

# Generate datasets and move them into appropriate group folders
for i in range(num_datasets):
    dataset_name = f"dataset_template_{i}.json"
    
    if LOAD_DATASET:
        print(f"Loading dataset {dataset_name}")
    else:
        print(f"Generating new dataset. This may take a while")
        # Run the subprocess commands (assumed not to change)
        subprocess.run(["python", "odor_space_analysis.py", "--params", f"saved_datasets/{dataset_name}"])
        subprocess.run([sys.executable, "generate_dataset.py", "--params", f"saved_datasets/{dataset_name}"])
    
    # Load the dataset_dict after running subprocess
    with open(f"saved_datasets/{dataset_name}") as f:
        dataset_dict = json.load(f)
    
    # Generate the filename for the generated voltage data
    voltage_file_name = f"dataset_size{dataset_dict['dataset_size']}_Nodor{dataset_dict['N_odorants']}_NOR{dataset_dict['N_OR']}_voltage.pkl"
    
    # Determine the group based on the index
    for group, idx_range in groups.items():
        if i in idx_range:
            group_dir = group_dirs[group]
            voltage_file_path = os.path.join(saved_datasets_dir, voltage_file_name)
            
            # Move the generated file to the appropriate group folder
            if os.path.exists(voltage_file_path):
                destination_file = os.path.join(group_dir, voltage_file_name)
                shutil.move(voltage_file_path, destination_file)
                print(f"Moved {voltage_file_name} to {group_dir}")
# Out:
# Generating new dataset. This may take a while
# Loading saved_datasets/dataset_template_0.json
# Loaded DoOR 2.0.1 dataset
# Performing analysis for odorants with idx [693 131 164  10]:
# none
# methanol
# propyl acetate
# gamma-butyrolactone
#
# Best receptors for N_OR = 3 :
# Selected receptor idx: [16 17 18]
# Selected receptors: ['Or35a' 'Or42a' 'Or42b']
# Saving results to saved_datasets/dataset_template_0.json
# /vast.mnt/home/20244579/new_SNN/synth_dataset.py:4: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.signal import butter,filtfilt
# Loading saved_datasets/dataset_template_0.json
#
# Generating dataset using DoOR 2.0.1 database
#
# dataset_size: 50
# output_dt: 0.005
# downsampling factor: 100
# N_ORCOs: 10
# odorant_idx: [693, 131, 164, 10]
# odorant names: ['none', 'methanol', 'propyl acetate', 'gamma-butyrolactone']
# OR_idx: [16, 17, 18]
# OR names: ['Or35a' 'Or42a' 'Or42b']
# output: voltage
# total simulation length: 0.5s
# ligand binding simulation length: 0.4s
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
# Calculating trace for odor [10]
#
# Setting up and running 4 processes
#
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 3, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
#
# Dataset size: 0.457763671875 MByte
# Saving dataset to saved_datasets/dataset_size50_Nodor4_NOR3_voltage.pkl.
# Saving dictionary to saved_datasets/dataset_template_0.json
# Total simulation time: 40.05335092544556 s
# Moved dataset_size50_Nodor4_NOR3_voltage.pkl to saved_datasets/group1
# Generating new dataset. This may take a while
# Loading saved_datasets/dataset_template_1.json
# Loaded DoOR 2.0.1 dataset
# Performing analysis for odorants with idx [693 131 164  10]:
# none
# methanol
# propyl acetate
# gamma-butyrolactone
#
# Best receptors for N_OR = 9 :
# Selected receptor idx: [ 3  7 16 17 18 20 24 40 49]
# Selected receptors: ['Or9a' 'Or22a' 'Or35a' 'Or42a' 'Or42b' 'Or43b' 'Or47a' 'Or85b' 'Or98a']
# Saving results to saved_datasets/dataset_template_1.json
# /vast.mnt/home/20244579/new_SNN/synth_dataset.py:4: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.signal import butter,filtfilt
# Loading saved_datasets/dataset_template_1.json
#
# Generating dataset using DoOR 2.0.1 database
#
# dataset_size: 50
# output_dt: 0.005
# downsampling factor: 100
# N_ORCOs: 10
# odorant_idx: [693, 131, 164, 10]
# odorant names: ['none', 'methanol', 'propyl acetate', 'gamma-butyrolactone']
# OR_idx: [3, 7, 16, 17, 18, 20, 24, 40, 49]
# OR names: ['Or9a' 'Or22a' 'Or35a' 'Or42a' 'Or42b' 'Or43b' 'Or47a' 'Or85b' 'Or98a']
# output: voltage
# total simulation length: 0.5s
# ligand binding simulation length: 0.4s
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [164]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
# Calculating trace for odor [131]
#
# Setting up and running 4 processes
#
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[  0, 164]]) , target name: propyl acetate
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# sample dimensions: torch.Size([1, 9, 100]) , target id: tensor([[ 0, 10]]) , target name: gamma-butyrolactone
# ...
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 693]]) , target name: none
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 131]]) , target name: methanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 132]]) , target name: ethanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
# sample dimensions: torch.Size([1, 21, 100]) , target id: tensor([[  0, 133]]) , target name: 1-propanol
#
# Dataset size: 3.204345703125 MByte
# Saving dataset to saved_datasets/dataset_size50_Nodor4_NOR21_voltage.pkl.
# Saving dictionary to saved_datasets/dataset_template_11.json
# Total simulation time: 278.6116693019867 s
# Moved dataset_size50_Nodor4_NOR21_voltage.pkl to saved_datasets/group3

# %% [markdown]
# # Run_batch F

# %%
############################################
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
torch.autograd.set_detect_anomaly(True)

# PARAMETERS FOR BACKPROP TRAINIG
gamma = .8  # gradient scale
lens = .5
decay_neu = 1.0  # no decay
#################################################

def run_batch(config): 
    num_dataset = 12
    ratio1 = 0.7                                 # for splitting the dataset into train set and test set
    ratio2 = 0.15
    hidden_dim = 50                            # number of hidden layer neurons

    # training configuration
    num_epochs = 15
    learning_rate = config['lr']
    num_iteration = 10

    # quantization parameters
    min_v = 0.0
    max_v = 0.6
    n_bits = 4 
    min_lr = 0.01
    max_lr = 0.2

    base_temp = 0.02
    scale_factor = 0.5

    # regularization parameters
    w_decay=1e-4

    result_set = []
    saved_datasets_dir = "saved_datasets/"  # The original location of dataset_template_0~11.json
    generated_datasets_dir = "saved_datasets/"  # The folder where generated files are moved (group1, group2, group3)

    # Loop through the dataset indices and load the corresponding files
    for i in range(num_dataset):
        # Determine the group and the folder where the generated dataset is stored
        for group, idx_range in groups.items():
            if i in idx_range:
                group_folder = os.path.join(generated_datasets_dir, group)
                break
        
        # Build the dataset name for the JSON template file
        dataset_name = f"dataset_template_{i}.json"
        dataset_path = os.path.join(saved_datasets_dir, dataset_name)
        
        # Load the corresponding dict from the dataset template
        with open(dataset_path) as f:
            dataset_dict = json.load(f)

        # Build the file name for the generated voltage data (assuming they are in group folders)
        voltage_file_name = f"dataset_size{dataset_dict['dataset_size']}_Nodor{dataset_dict['N_odorants']}_NOR{dataset_dict['N_OR']}_voltage.pkl"
        voltage_file_path = os.path.join(group_folder, voltage_file_name)

        print(f"Loading dataset_template_{i}.json -> {voltage_file_path} completed")

        # Load the generated dataset
        with open(voltage_file_path, 'rb') as f:
            dataset = dill.load(f)

        dataset_size_total = dataset_dict['dataset_size'] * dataset_dict['N_odorants']

        # Splitting the dataset into train, validation, and test sizes
        train_size = int(dataset_size_total * ratio1)
        val_size = int(ratio2 * dataset_size_total)
        print(f"Total number of train samples is : {train_size}")
        print(f"Total number of validation samples is : {val_size}")
        print(f"Total number of test samples is : {dataset_size_total - train_size - val_size}")

        # Extract odorant names and indices
        odorant_name = dataset_dict['odorant_names']
        odorant_idx = dataset_dict['odorant_idx']

        dt = dataset_dict['dt']
        output_dt = dataset_dict['output_dt']
        down_sampling_rate = output_dt / dt

        total_timesteps = dataset_dict['total_steps'] / down_sampling_rate
        timestamps = np.arange(0, total_timesteps * output_dt, output_dt)

        dimx = dataset_dict['N_OR'] # n_ORs
        dimy = int(total_timesteps) # number of timesteps
        n_classes = dataset_dict['N_odorants']
        print(f'dimx = {dimx}, dimy = {dimy}, n_classes = {n_classes}')

        # Calculate the batch size (1/10 of training samples)
        batch_size = int(train_size / 10)

        # Find the largest power of 2 less than or equal to the batch size
        batch_size_lower_power_of_2 = 2 ** (math.floor(math.log2(batch_size)))

        # Check if the 1/10 batch size is more than 70% larger than the lower power of 2
        if batch_size >= 1.7 * batch_size_lower_power_of_2:
            # Find the smallest power of 2 greater than or equal to the batch size
            batch_size_power_of_2 = 2 ** (math.ceil(math.log2(batch_size)))
        else:
            # Use the lower power of 2
            batch_size_power_of_2 = batch_size_lower_power_of_2

        print(f"Using batch size: {batch_size_power_of_2}")

        test_acc = []
        for j in range(num_iteration):
            w_tracker = []
            w_tracker_q = []
            temp = 0

            train_size = int(ratio1 * dataset_size_total)
            val_size = int(ratio2 * dataset_size_total)
            test_size = dataset_size_total - train_size - val_size  # Ensure all samples are used
            dataset_train, dataset_val, dataset_test = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

            train_loader = DataLoader(dataset_train, batch_size = batch_size_power_of_2, shuffle=True)
            test_loader = DataLoader(dataset_test, batch_size = batch_size_power_of_2, shuffle=True)
            val_loader = DataLoader(dataset_val, batch_size = batch_size_power_of_2, shuffle=True)
            
            model = mlpsnn(n_inputs=dimx, hidden_dim=hidden_dim,  n_outputs=n_classes)
            model.to(device)
            
            base_params = [model.i2h.weight, model.h2o.weight]
            optimizer = torch.optim.Adam([
                {'params': base_params},
                ],
                lr=learning_rate,
                # weight_decay = w_decay
                )

            # Proceed with training
            i2h_weight = model.i2h.weight.data
            h2o_weight = model.h2o.weight.data

            stacked_weights_norm = torch.cat([model.i2h.weight.data.flatten(), model.h2o.weight.data.flatten()])
            stacked_weights_norm = normalize_tensor_safe(stacked_weights_norm, -1 * max_v, max_v)
            # Split them back
            model.i2h.weight.data = stacked_weights_norm[:i2h_weight.numel()].reshape(i2h_weight.shape)
            model.h2o.weight.data = stacked_weights_norm[i2h_weight.numel():].reshape(h2o_weight.shape)

            temp, w_tracker, w_tracker_q = train_test_val(config, model, train_loader, test_loader, val_loader, odorant_idx, optimizer, min_v, max_v, num_epochs, criterion=criterion, n_bits=n_bits, gamma=config['gamma'], min_lr=min_lr, max_lr=max_lr, base_temp=base_temp, scale_factor=scale_factor)            
            test_acc.append(temp)

            print(f"The {j+1} iteration completed.\n")
        print(f"Test accuracy for {num_iteration} runs are : {test_acc}")
        result_set.append([float(element) for element in test_acc])

    print(f'Final result : {result_set}')
    return result_set

# %% [markdown]
# # Param Sweep for optimization

# %%
import numpy as np

def remove_outliers_and_calculate_mean(data):
    # Assuming data is of shape (num_dataset, num_iteration)
    
    # Initialize a list to store means of each dataset after removing outliers
    dataset_means = []
    
    # Loop over each dataset
    for dataset in data:
        # Flatten the dataset across iterations
        dataset = np.concatenate([np.array(item).flatten() for item in dataset])
        
        # Calculate percentiles for the dataset
        Q1 = np.percentile(dataset, 25)  # First quartile (25th percentile)
        Q3 = np.percentile(dataset, 75)  # Third quartile (75th percentile)
        IQR = Q3 - Q1  # Interquartile range

        # Define the bounds for filtering
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter out the outliers
        filtered_data = dataset[(dataset >= lower_bound) & (dataset <= upper_bound)]

        # Calculate the mean of the filtered data for this dataset
        dataset_means.append(np.mean(filtered_data))
    
    # After all datasets, calculate the overall mean of all dataset means (no outlier removal here)
    all_data = np.concatenate([np.array(dataset).flatten() for dataset in data])
    
    overall_mean = np.mean(all_data)
    
    return overall_mean

# %%
import itertools

# Objective function for calculating the score
def objective(config):
    result = run_batch(config)
    score = remove_outliers_and_calculate_mean(result)
    return score

# Main sweep function
def run_sweep(parameter_grid):
    # Generate all combinations of parameters using itertools.product
    all_combinations = list(itertools.product(*parameter_grid.values()))
    
    # Initialize an empty list to store the results (scores)
    results = []

    # Iterate through all parameter combinations
    for combination in all_combinations:
        # Convert the combination to a dictionary
        config = dict(zip(parameter_grid.keys(), combination))

        # Print the current parameter combination being tested
        print(f"Testing configuration: {config}")

        # Calculate the score for this combination
        score = objective(config)

        # Store the config and corresponding score
        results.append({'config': config, 'score': score})

    # Sort results based on score
    results.sort(key=lambda x: x['score'], reverse=True)

    # Print or return the results (e.g., best score)
    return results

# Parameter grid for sweeping
parameter_grid = {
    "lr": [0.05, 0.06],                  #[0.005, 0.01, 0.05],
    "use_scheduler": [True],
    "use_regularizer": [False],
    "use_quantization": [True],
    "quantization_type": ["linear"],
    "use_lr_scaling": [False],
    "gamma": [0.9],
    "amp": [5000],             #[0.001e6, 0.005e6, 0.01e6, 0.08e6, 0.12e6],
}

# Run the sweep and get the results
results = run_sweep(parameter_grid)

# Output the best results
best_result = results[0]
print(f"Best Configuration: {best_result['config']}")
print(f"Best Score: {best_result['score']}")
# Out:
# Testing configuration: {'lr': 0.05, 'use_scheduler': True, 'use_regularizer': False, 'use_quantization': True, 'quantization_type': 'linear', 'use_lr_scaling': False, 'gamma': 0.9, 'amp': 5000}
# Loading dataset_template_0.json -> saved_datasets/group1/dataset_size50_Nodor4_NOR3_voltage.pkl completed
# Total number of train samples is : 140
# Total number of validation samples is : 30
# Total number of test samples is : 30
# dimx = 3, dimy = 100, n_classes = 4
# Using batch size: 16
# /scratch-node/20244579.2293436/ipykernel_3431610/2732983013.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   traces = torch.tensor(traces).to(device)#view((-1, x_emp.shape[0], input_dim)).requires_grad_().to(device)
# Validation acc before training: 0.3392857142857143
# Test acc before training: 0.26339285714285715
# epoch:   0, Train Loss: 0.0762, Train Acc: 0.4571, Current val_accuracy: 0.7054, Current test_accuracy: 0.4955
# epoch:   1, Train Loss: 0.0706, Train Acc: 0.4571, Current val_accuracy: 0.7054, Current test_accuracy: 0.5045
# epoch:   2, Train Loss: 0.0709, Train Acc: 0.4571, Current val_accuracy: 0.7009, Current test_accuracy: 0.5000
# epoch:   3, Train Loss: 0.0711, Train Acc: 0.4571, Current val_accuracy: 0.7098, Current test_accuracy: 0.5089
# epoch:   4, Train Loss: 0.0710, Train Acc: 0.4571, Current val_accuracy: 0.6920, Current test_accuracy: 0.4955
# epoch:   5, Train Loss: 0.0705, Train Acc: 0.4571, Current val_accuracy: 0.6964, Current test_accuracy: 0.4955
# epoch:   6, Train Loss: 0.0711, Train Acc: 0.4571, Current val_accuracy: 0.7098, Current test_accuracy: 0.5089
# epoch:   7, Train Loss: 0.0709, Train Acc: 0.4571, Current val_accuracy: 0.7098, Current test_accuracy: 0.5045
# epoch:   8, Train Loss: 0.0706, Train Acc: 0.4571, Current val_accuracy: 0.6964, Current test_accuracy: 0.5000
# epoch:   9, Train Loss: 0.0706, Train Acc: 0.4571, Current val_accuracy: 0.6920, Current test_accuracy: 0.5000
# epoch:  10, Train Loss: 0.0705, Train Acc: 0.4571, Current val_accuracy: 0.7054, Current test_accuracy: 0.5045
# epoch:  11, Train Loss: 0.0711, Train Acc: 0.4571, Current val_accuracy: 0.6920, Current test_accuracy: 0.4911
# epoch:  12, Train Loss: 0.0705, Train Acc: 0.4571, Current val_accuracy: 0.6964, Current test_accuracy: 0.5045
# epoch:  13, Train Loss: 0.0711, Train Acc: 0.4571, Current val_accuracy: 0.7054, Current test_accuracy: 0.4821
# epoch:  14, Train Loss: 0.0706, Train Acc: 0.4571, Current val_accuracy: 0.6964, Current test_accuracy: 0.5000
# The 1 iteration completed.
#
# Validation acc before training: 0.6651785714285714
# Test acc before training: 0.5357142857142857
# epoch:   0, Train Loss: 0.0682, Train Acc: 0.6857, Current val_accuracy: 0.9018, Current test_accuracy: 0.7009
# epoch:   1, Train Loss: 0.0501, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.6964
# epoch:   2, Train Loss: 0.0499, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.7009
# epoch:   3, Train Loss: 0.0502, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.7009
# epoch:   4, Train Loss: 0.0502, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.7143
# epoch:   5, Train Loss: 0.0498, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.6964
# epoch:   6, Train Loss: 0.0500, Train Acc: 0.7071, Current val_accuracy: 0.9062, Current test_accuracy: 0.7054
# epoch:   7, Train Loss: 0.0502, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.7009
# epoch:   8, Train Loss: 0.0494, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.6964
# epoch:   9, Train Loss: 0.0503, Train Acc: 0.7071, Current val_accuracy: 0.9062, Current test_accuracy: 0.6964
# epoch:  10, Train Loss: 0.0501, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.7054
# epoch:  11, Train Loss: 0.0499, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.6920
# epoch:  12, Train Loss: 0.0499, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.6964
# epoch:  13, Train Loss: 0.0503, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.7098
# epoch:  14, Train Loss: 0.0498, Train Acc: 0.7071, Current val_accuracy: 0.8973, Current test_accuracy: 0.7009
# The 2 iteration completed.
#
# Validation acc before training: 0.5625
# Test acc before training: 0.5
# epoch:   0, Train Loss: 0.0560, Train Acc: 0.7071, Current val_accuracy: 0.7009, Current test_accuracy: 0.6652
# epoch:   1, Train Loss: 0.0497, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6696
# epoch:   2, Train Loss: 0.0504, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6696
# epoch:   3, Train Loss: 0.0500, Train Acc: 0.7786, Current val_accuracy: 0.6964, Current test_accuracy: 0.6696
# epoch:   4, Train Loss: 0.0500, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6607
# epoch:   5, Train Loss: 0.0495, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6696
# epoch:   6, Train Loss: 0.0497, Train Acc: 0.7786, Current val_accuracy: 0.7098, Current test_accuracy: 0.6607
# epoch:   7, Train Loss: 0.0496, Train Acc: 0.7786, Current val_accuracy: 0.6920, Current test_accuracy: 0.6652
# epoch:   8, Train Loss: 0.0495, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6741
# epoch:   9, Train Loss: 0.0500, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6696
# epoch:  10, Train Loss: 0.0498, Train Acc: 0.7786, Current val_accuracy: 0.6964, Current test_accuracy: 0.6786
# epoch:  11, Train Loss: 0.0503, Train Acc: 0.7786, Current val_accuracy: 0.6920, Current test_accuracy: 0.6518
# epoch:  12, Train Loss: 0.0503, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6652
# epoch:  13, Train Loss: 0.0499, Train Acc: 0.7786, Current val_accuracy: 0.6920, Current test_accuracy: 0.6518
# epoch:  14, Train Loss: 0.0494, Train Acc: 0.7786, Current val_accuracy: 0.6964, Current test_accuracy: 0.6741
# The 3 iteration completed.
#
# Validation acc before training: 0.3705357142857143
# Test acc before training: 0.3348214285714286
# epoch:   0, Train Loss: 0.1029, Train Acc: 0.6214, Current val_accuracy: 0.7009, Current test_accuracy: 0.6696
# epoch:   1, Train Loss: 0.0719, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6696
# epoch:   2, Train Loss: 0.0672, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6652
# epoch:   3, Train Loss: 0.0672, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6786
# epoch:   4, Train Loss: 0.0665, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6607
# epoch:   5, Train Loss: 0.0664, Train Acc: 0.7786, Current val_accuracy: 0.7098, Current test_accuracy: 0.6562
# epoch:   6, Train Loss: 0.0676, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6652
# epoch:   7, Train Loss: 0.0673, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6741
# epoch:   8, Train Loss: 0.0677, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6741
# epoch:   9, Train Loss: 0.0668, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6741
# epoch:  10, Train Loss: 0.0675, Train Acc: 0.7786, Current val_accuracy: 0.7009, Current test_accuracy: 0.6696
# epoch:  11, Train Loss: 0.0670, Train Acc: 0.7786, Current val_accuracy: 0.6964, Current test_accuracy: 0.6652
# epoch:  12, Train Loss: 0.0672, Train Acc: 0.7786, Current val_accuracy: 0.7054, Current test_accuracy: 0.6652
# epoch:  13, Train Loss: 0.0673, Train Acc: 0.7786, Current val_accuracy: 0.7098, Current test_accuracy: 0.6562
# epoch:  14, Train Loss: 0.0670, Train Acc: 0.7786, Current val_accuracy: 0.6964, Current test_accuracy: 0.6607
# The 4 iteration completed.
#
# Validation acc before training: 0.3348214285714286
# Test acc before training: 0.5580357142857143
# epoch:   0, Train Loss: 0.0763, Train Acc: 0.6571, Current val_accuracy: 0.7321, Current test_accuracy: 0.8661
# epoch:   1, Train Loss: 0.0542, Train Acc: 0.7500, Current val_accuracy: 0.5312, Current test_accuracy: 0.6786
# epoch:   2, Train Loss: 0.0632, Train Acc: 0.6714, Current val_accuracy: 0.6964, Current test_accuracy: 0.7723
# epoch:   3, Train Loss: 0.0588, Train Acc: 0.7357, Current val_accuracy: 0.6920, Current test_accuracy: 0.7679
# epoch:   4, Train Loss: 0.0586, Train Acc: 0.7357, Current val_accuracy: 0.7054, Current test_accuracy: 0.7679
# epoch:   5, Train Loss: 0.0591, Train Acc: 0.7357, Current val_accuracy: 0.6964, Current test_accuracy: 0.7634
# epoch:   6, Train Loss: 0.0587, Train Acc: 0.7357, Current val_accuracy: 0.6830, Current test_accuracy: 0.7723
# epoch:   7, Train Loss: 0.0592, Train Acc: 0.7357, Current val_accuracy: 0.6964, Current test_accuracy: 0.7768
# epoch:   8, Train Loss: 0.0587, Train Acc: 0.7357, Current val_accuracy: 0.7054, Current test_accuracy: 0.7723
# epoch:   9, Train Loss: 0.0588, Train Acc: 0.7357, Current val_accuracy: 0.7009, Current test_accuracy: 0.7679
# epoch:  10, Train Loss: 0.0589, Train Acc: 0.7357, Current val_accuracy: 0.7009, Current test_accuracy: 0.7679
# epoch:  11, Train Loss: 0.0587, Train Acc: 0.7357, Current val_accuracy: 0.6920, Current test_accuracy: 0.7768
# epoch:  12, Train Loss: 0.0581, Train Acc: 0.7357, Current val_accuracy: 0.6964, Current test_accuracy: 0.7589
# epoch:  13, Train Loss: 0.0589, Train Acc: 0.7357, Current val_accuracy: 0.6920, Current test_accuracy: 0.7589
# epoch:  14, Train Loss: 0.0586, Train Acc: 0.7357, Current val_accuracy: 0.6964, Current test_accuracy: 0.7679
# The 5 iteration completed.
#
# Validation acc before training: 0.1919642857142857
# Test acc before training: 0.26785714285714285
# epoch:   0, Train Loss: 0.0703, Train Acc: 0.6286, Current val_accuracy: 0.6920, Current test_accuracy: 0.9330
# epoch:   1, Train Loss: 0.0550, Train Acc: 0.7857, Current val_accuracy: 0.5938, Current test_accuracy: 0.9018
# epoch:   2, Train Loss: 0.0572, Train Acc: 0.7143, Current val_accuracy: 0.9018, Current test_accuracy: 0.7411
# epoch:   3, Train Loss: 0.0507, Train Acc: 0.9286, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0485, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0486, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0483, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0488, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0487, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0480, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0487, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0478, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0482, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0482, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0485, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 6 iteration completed.
#
# Validation acc before training: 0.3080357142857143
# Test acc before training: 0.1919642857142857
# epoch:   0, Train Loss: 0.0830, Train Acc: 0.4429, Current val_accuracy: 0.5402, Current test_accuracy: 0.4688
# epoch:   1, Train Loss: 0.0679, Train Acc: 0.4929, Current val_accuracy: 0.5312, Current test_accuracy: 0.4911
# epoch:   2, Train Loss: 0.0679, Train Acc: 0.4929, Current val_accuracy: 0.5223, Current test_accuracy: 0.5000
# epoch:   3, Train Loss: 0.0675, Train Acc: 0.4929, Current val_accuracy: 0.5223, Current test_accuracy: 0.4955
# epoch:   4, Train Loss: 0.0666, Train Acc: 0.5000, Current val_accuracy: 0.5357, Current test_accuracy: 0.4955
# epoch:   5, Train Loss: 0.0672, Train Acc: 0.5000, Current val_accuracy: 0.5357, Current test_accuracy: 0.5045
# epoch:   6, Train Loss: 0.0668, Train Acc: 0.5000, Current val_accuracy: 0.5312, Current test_accuracy: 0.4821
# epoch:   7, Train Loss: 0.0668, Train Acc: 0.5000, Current val_accuracy: 0.5312, Current test_accuracy: 0.5089
# epoch:   8, Train Loss: 0.0674, Train Acc: 0.5000, Current val_accuracy: 0.5357, Current test_accuracy: 0.5045
# epoch:   9, Train Loss: 0.0674, Train Acc: 0.5000, Current val_accuracy: 0.5402, Current test_accuracy: 0.4955
# epoch:  10, Train Loss: 0.0674, Train Acc: 0.5000, Current val_accuracy: 0.5357, Current test_accuracy: 0.5000
# epoch:  11, Train Loss: 0.0676, Train Acc: 0.5000, Current val_accuracy: 0.5312, Current test_accuracy: 0.5000
# epoch:  12, Train Loss: 0.0670, Train Acc: 0.5000, Current val_accuracy: 0.5357, Current test_accuracy: 0.4955
# epoch:  13, Train Loss: 0.0670, Train Acc: 0.5000, Current val_accuracy: 0.5223, Current test_accuracy: 0.5000
# epoch:  14, Train Loss: 0.0672, Train Acc: 0.5000, Current val_accuracy: 0.5268, Current test_accuracy: 0.5045
# The 7 iteration completed.
#
# Validation acc before training: 0.23214285714285715
# Test acc before training: 0.2723214285714286
# epoch:   0, Train Loss: 0.0853, Train Acc: 0.6429, Current val_accuracy: 0.6696, Current test_accuracy: 0.7232
# epoch:   1, Train Loss: 0.0506, Train Acc: 0.8929, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   2, Train Loss: 0.0456, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   3, Train Loss: 0.0461, Train Acc: 0.9643, Current val_accuracy: 0.6071, Current test_accuracy: 0.6741
# epoch:   4, Train Loss: 0.0513, Train Acc: 0.8000, Current val_accuracy: 0.5982, Current test_accuracy: 0.6741
# epoch:   5, Train Loss: 0.0473, Train Acc: 0.9214, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   6, Train Loss: 0.0455, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   7, Train Loss: 0.0459, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   8, Train Loss: 0.0454, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   9, Train Loss: 0.0457, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:  10, Train Loss: 0.0456, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:  11, Train Loss: 0.0458, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0458, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:  13, Train Loss: 0.0457, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:  14, Train Loss: 0.0459, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# The 8 iteration completed.
#
# Validation acc before training: 0.5982142857142857
# Test acc before training: 0.5089285714285714
# epoch:   0, Train Loss: 0.0993, Train Acc: 0.7214, Current val_accuracy: 0.7009, Current test_accuracy: 0.7634
# epoch:   1, Train Loss: 0.0512, Train Acc: 0.8357, Current val_accuracy: 0.8929, Current test_accuracy: 0.8750
# epoch:   2, Train Loss: 0.0481, Train Acc: 0.9214, Current val_accuracy: 0.8973, Current test_accuracy: 0.8705
# epoch:   3, Train Loss: 0.0425, Train Acc: 0.9857, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0406, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0405, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0407, Train Acc: 1.0000, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0408, Train Acc: 1.0000, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0409, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0406, Train Acc: 1.0000, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0404, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0403, Train Acc: 1.0000, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0410, Train Acc: 1.0000, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0409, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0410, Train Acc: 1.0000, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# The 9 iteration completed.
#
# Validation acc before training: 0.26785714285714285
# Test acc before training: 0.3973214285714286
# epoch:   0, Train Loss: 0.0764, Train Acc: 0.6143, Current val_accuracy: 0.8080, Current test_accuracy: 0.8304
# epoch:   1, Train Loss: 0.0516, Train Acc: 0.7000, Current val_accuracy: 0.8036, Current test_accuracy: 0.8304
# epoch:   2, Train Loss: 0.0519, Train Acc: 0.7000, Current val_accuracy: 0.8036, Current test_accuracy: 0.8304
# epoch:   3, Train Loss: 0.0519, Train Acc: 0.7000, Current val_accuracy: 0.7991, Current test_accuracy: 0.8393
# epoch:   4, Train Loss: 0.0519, Train Acc: 0.7000, Current val_accuracy: 0.7946, Current test_accuracy: 0.8393
# epoch:   5, Train Loss: 0.0516, Train Acc: 0.7000, Current val_accuracy: 0.7946, Current test_accuracy: 0.8259
# epoch:   6, Train Loss: 0.0516, Train Acc: 0.7000, Current val_accuracy: 0.7902, Current test_accuracy: 0.8393
# epoch:   7, Train Loss: 0.0517, Train Acc: 0.7000, Current val_accuracy: 0.8036, Current test_accuracy: 0.8304
# epoch:   8, Train Loss: 0.0519, Train Acc: 0.7000, Current val_accuracy: 0.8080, Current test_accuracy: 0.8259
# epoch:   9, Train Loss: 0.0514, Train Acc: 0.7000, Current val_accuracy: 0.8036, Current test_accuracy: 0.8259
# epoch:  10, Train Loss: 0.0517, Train Acc: 0.7000, Current val_accuracy: 0.7991, Current test_accuracy: 0.8259
# epoch:  11, Train Loss: 0.0517, Train Acc: 0.7000, Current val_accuracy: 0.7946, Current test_accuracy: 0.8259
# epoch:  12, Train Loss: 0.0518, Train Acc: 0.7000, Current val_accuracy: 0.7991, Current test_accuracy: 0.8304
# epoch:  13, Train Loss: 0.0516, Train Acc: 0.7000, Current val_accuracy: 0.7946, Current test_accuracy: 0.8304
# epoch:  14, Train Loss: 0.0516, Train Acc: 0.7000, Current val_accuracy: 0.7946, Current test_accuracy: 0.8393
# The 10 iteration completed.
#
# Test accuracy for 10 runs are : [0.5089285714285714, 0.7053571428571428, 0.6607142857142857, 0.65625, 0.7678571428571428, 1.0, 0.4955357142857143, 0.96875, 1.0, 0.8258928571428572]
# Loading dataset_template_1.json -> saved_datasets/group1/dataset_size50_Nodor4_NOR9_voltage.pkl completed
# Total number of train samples is : 140
# Total number of validation samples is : 30
# Total number of test samples is : 30
# dimx = 9, dimy = 100, n_classes = 4
# Using batch size: 16
# Validation acc before training: 0.20535714285714285
# Test acc before training: 0.16964285714285715
# epoch:   0, Train Loss: 0.0679, Train Acc: 0.8143, Current val_accuracy: 0.9330, Current test_accuracy: 0.8705
# epoch:   1, Train Loss: 0.0402, Train Acc: 0.9000, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:   2, Train Loss: 0.0397, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:   3, Train Loss: 0.0404, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8438
# epoch:   4, Train Loss: 0.0399, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8348
# epoch:   5, Train Loss: 0.0393, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:   6, Train Loss: 0.0409, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8348
# epoch:   7, Train Loss: 0.0402, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8259
# epoch:   8, Train Loss: 0.0399, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8438
# epoch:   9, Train Loss: 0.0400, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8393
# epoch:  10, Train Loss: 0.0397, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8304
# epoch:  11, Train Loss: 0.0399, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8393
# epoch:  12, Train Loss: 0.0403, Train Acc: 0.9071, Current val_accuracy: 0.9643, Current test_accuracy: 0.8393
# epoch:  13, Train Loss: 0.0410, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:  14, Train Loss: 0.0401, Train Acc: 0.9071, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# The 1 iteration completed.
#
# Validation acc before training: 0.3973214285714286
# Test acc before training: 0.3705357142857143
# epoch:   0, Train Loss: 0.0730, Train Acc: 0.8071, Current val_accuracy: 1.0000, Current test_accuracy: 0.9286
# epoch:   1, Train Loss: 0.0341, Train Acc: 0.9286, Current val_accuracy: 0.9643, Current test_accuracy: 0.9330
# epoch:   2, Train Loss: 0.0339, Train Acc: 0.9429, Current val_accuracy: 0.9643, Current test_accuracy: 0.9286
# epoch:   3, Train Loss: 0.0336, Train Acc: 0.9429, Current val_accuracy: 0.9688, Current test_accuracy: 0.9330
# epoch:   4, Train Loss: 0.0315, Train Acc: 0.9571, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   5, Train Loss: 0.0312, Train Acc: 0.9643, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   6, Train Loss: 0.0311, Train Acc: 0.9643, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:   7, Train Loss: 0.0314, Train Acc: 0.9643, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# epoch:   8, Train Loss: 0.0314, Train Acc: 0.9643, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0311, Train Acc: 0.9643, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:  10, Train Loss: 0.0314, Train Acc: 0.9643, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:  11, Train Loss: 0.0319, Train Acc: 0.9643, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0312, Train Acc: 0.9643, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:  13, Train Loss: 0.0311, Train Acc: 0.9643, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:  14, Train Loss: 0.0313, Train Acc: 0.9643, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# The 2 iteration completed.
#
# Validation acc before training: 0.40625
# Test acc before training: 0.5714285714285714
# epoch:   0, Train Loss: 0.0965, Train Acc: 0.6786, Current val_accuracy: 0.5625, Current test_accuracy: 0.7098
# epoch:   1, Train Loss: 0.0619, Train Acc: 0.6929, Current val_accuracy: 0.6295, Current test_accuracy: 0.7009
# epoch:   2, Train Loss: 0.0604, Train Acc: 0.7071, Current val_accuracy: 0.6071, Current test_accuracy: 0.6964
# epoch:   3, Train Loss: 0.0604, Train Acc: 0.6929, Current val_accuracy: 0.5938, Current test_accuracy: 0.7009
# epoch:   4, Train Loss: 0.0614, Train Acc: 0.6929, Current val_accuracy: 0.5848, Current test_accuracy: 0.7098
# epoch:   5, Train Loss: 0.0616, Train Acc: 0.6929, Current val_accuracy: 0.6071, Current test_accuracy: 0.7009
# epoch:   6, Train Loss: 0.0611, Train Acc: 0.6929, Current val_accuracy: 0.6027, Current test_accuracy: 0.6920
# epoch:   7, Train Loss: 0.0605, Train Acc: 0.6929, Current val_accuracy: 0.5982, Current test_accuracy: 0.7009
# epoch:   8, Train Loss: 0.0605, Train Acc: 0.6929, Current val_accuracy: 0.5938, Current test_accuracy: 0.7054
# epoch:   9, Train Loss: 0.0613, Train Acc: 0.6929, Current val_accuracy: 0.5982, Current test_accuracy: 0.7054
# epoch:  10, Train Loss: 0.0614, Train Acc: 0.6929, Current val_accuracy: 0.5938, Current test_accuracy: 0.7054
# epoch:  11, Train Loss: 0.0605, Train Acc: 0.6929, Current val_accuracy: 0.5938, Current test_accuracy: 0.7009
# epoch:  12, Train Loss: 0.0606, Train Acc: 0.6929, Current val_accuracy: 0.6027, Current test_accuracy: 0.7009
# epoch:  13, Train Loss: 0.0605, Train Acc: 0.6929, Current val_accuracy: 0.5938, Current test_accuracy: 0.7054
# epoch:  14, Train Loss: 0.0606, Train Acc: 0.6929, Current val_accuracy: 0.5982, Current test_accuracy: 0.7054
# The 3 iteration completed.
#
# Validation acc before training: 0.5044642857142857
# Test acc before training: 0.4419642857142857
# epoch:   0, Train Loss: 0.0633, Train Acc: 0.7429, Current val_accuracy: 0.8304, Current test_accuracy: 0.8616
# epoch:   1, Train Loss: 0.0444, Train Acc: 0.8643, Current val_accuracy: 0.7946, Current test_accuracy: 0.9018
# epoch:   2, Train Loss: 0.0416, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.8973
# epoch:   3, Train Loss: 0.0418, Train Acc: 0.8571, Current val_accuracy: 0.7902, Current test_accuracy: 0.9062
# epoch:   4, Train Loss: 0.0424, Train Acc: 0.8571, Current val_accuracy: 0.8080, Current test_accuracy: 0.8929
# epoch:   5, Train Loss: 0.0426, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.9062
# epoch:   6, Train Loss: 0.0424, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.8973
# epoch:   7, Train Loss: 0.0417, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.9018
# epoch:   8, Train Loss: 0.0422, Train Acc: 0.8571, Current val_accuracy: 0.7946, Current test_accuracy: 0.9018
# epoch:   9, Train Loss: 0.0420, Train Acc: 0.8571, Current val_accuracy: 0.8036, Current test_accuracy: 0.9062
# epoch:  10, Train Loss: 0.0416, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.8973
# epoch:  11, Train Loss: 0.0422, Train Acc: 0.8571, Current val_accuracy: 0.8036, Current test_accuracy: 0.9018
# epoch:  12, Train Loss: 0.0421, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.9018
# epoch:  13, Train Loss: 0.0424, Train Acc: 0.8571, Current val_accuracy: 0.7991, Current test_accuracy: 0.9062
# epoch:  14, Train Loss: 0.0417, Train Acc: 0.8571, Current val_accuracy: 0.8036, Current test_accuracy: 0.9062
# The 4 iteration completed.
#
# Validation acc before training: 0.42410714285714285
# Test acc before training: 0.53125
# epoch:   0, Train Loss: 0.1194, Train Acc: 0.5714, Current val_accuracy: 0.7277, Current test_accuracy: 0.6339
# epoch:   1, Train Loss: 0.0844, Train Acc: 0.6714, Current val_accuracy: 0.7143, Current test_accuracy: 0.5938
# epoch:   2, Train Loss: 0.0785, Train Acc: 0.6929, Current val_accuracy: 0.7009, Current test_accuracy: 0.5982
# epoch:   3, Train Loss: 0.0793, Train Acc: 0.6857, Current val_accuracy: 0.7188, Current test_accuracy: 0.5938
# epoch:   4, Train Loss: 0.0787, Train Acc: 0.6714, Current val_accuracy: 0.7411, Current test_accuracy: 0.6116
# epoch:   5, Train Loss: 0.0785, Train Acc: 0.6643, Current val_accuracy: 0.7455, Current test_accuracy: 0.5982
# epoch:   6, Train Loss: 0.0792, Train Acc: 0.6643, Current val_accuracy: 0.7232, Current test_accuracy: 0.5938
# epoch:   7, Train Loss: 0.0788, Train Acc: 0.6643, Current val_accuracy: 0.7321, Current test_accuracy: 0.5982
# epoch:   8, Train Loss: 0.0789, Train Acc: 0.6643, Current val_accuracy: 0.7366, Current test_accuracy: 0.6071
# epoch:   9, Train Loss: 0.0790, Train Acc: 0.6643, Current val_accuracy: 0.7277, Current test_accuracy: 0.6027
# epoch:  10, Train Loss: 0.0788, Train Acc: 0.6643, Current val_accuracy: 0.7321, Current test_accuracy: 0.6027
# epoch:  11, Train Loss: 0.0790, Train Acc: 0.6643, Current val_accuracy: 0.7411, Current test_accuracy: 0.6116
# epoch:  12, Train Loss: 0.0803, Train Acc: 0.6643, Current val_accuracy: 0.7366, Current test_accuracy: 0.5982
# epoch:  13, Train Loss: 0.0790, Train Acc: 0.6643, Current val_accuracy: 0.7321, Current test_accuracy: 0.5982
# epoch:  14, Train Loss: 0.0788, Train Acc: 0.6643, Current val_accuracy: 0.7366, Current test_accuracy: 0.5982
# The 5 iteration completed.
#
# Validation acc before training: 0.53125
# Test acc before training: 0.4419642857142857
# epoch:   0, Train Loss: 0.0926, Train Acc: 0.6643, Current val_accuracy: 0.8661, Current test_accuracy: 0.8080
# epoch:   1, Train Loss: 0.0435, Train Acc: 0.8857, Current val_accuracy: 0.9018, Current test_accuracy: 0.9018
# epoch:   2, Train Loss: 0.0389, Train Acc: 0.9286, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   3, Train Loss: 0.0366, Train Acc: 0.9571, Current val_accuracy: 0.9330, Current test_accuracy: 0.9330
# epoch:   4, Train Loss: 0.0349, Train Acc: 0.9643, Current val_accuracy: 0.9375, Current test_accuracy: 0.9375
# epoch:   5, Train Loss: 0.0355, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9330
# epoch:   6, Train Loss: 0.0354, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9330
# epoch:   7, Train Loss: 0.0354, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9286
# epoch:   8, Train Loss: 0.0351, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9286
# epoch:   9, Train Loss: 0.0358, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9375
# epoch:  10, Train Loss: 0.0351, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9330
# epoch:  11, Train Loss: 0.0353, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9286
# epoch:  12, Train Loss: 0.0354, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9286
# epoch:  13, Train Loss: 0.0353, Train Acc: 0.9643, Current val_accuracy: 0.9330, Current test_accuracy: 0.9330
# epoch:  14, Train Loss: 0.0353, Train Acc: 0.9643, Current val_accuracy: 0.9286, Current test_accuracy: 0.9330
# The 6 iteration completed.
#
# Validation acc before training: 0.4955357142857143
# Test acc before training: 0.6071428571428572
# epoch:   0, Train Loss: 0.1050, Train Acc: 0.6000, Current val_accuracy: 0.7098, Current test_accuracy: 0.8080
# epoch:   1, Train Loss: 0.0609, Train Acc: 0.7143, Current val_accuracy: 0.7009, Current test_accuracy: 0.7946
# epoch:   2, Train Loss: 0.0582, Train Acc: 0.7214, Current val_accuracy: 0.6607, Current test_accuracy: 0.7946
# epoch:   3, Train Loss: 0.0560, Train Acc: 0.7357, Current val_accuracy: 0.7366, Current test_accuracy: 0.7991
# epoch:   4, Train Loss: 0.0563, Train Acc: 0.7214, Current val_accuracy: 0.6607, Current test_accuracy: 0.8705
# epoch:   5, Train Loss: 0.0554, Train Acc: 0.7643, Current val_accuracy: 0.7277, Current test_accuracy: 0.8929
# epoch:   6, Train Loss: 0.0506, Train Acc: 0.8214, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   7, Train Loss: 0.0437, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:   8, Train Loss: 0.0410, Train Acc: 0.9000, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0412, Train Acc: 0.9000, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:  10, Train Loss: 0.0415, Train Acc: 0.9000, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:  11, Train Loss: 0.0410, Train Acc: 0.9000, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0417, Train Acc: 0.9000, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:  13, Train Loss: 0.0411, Train Acc: 0.9000, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:  14, Train Loss: 0.0411, Train Acc: 0.9000, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# The 7 iteration completed.
#
# Validation acc before training: 0.6071428571428572
# Test acc before training: 0.59375
# epoch:   0, Train Loss: 0.1454, Train Acc: 0.7143, Current val_accuracy: 0.8036, Current test_accuracy: 0.8616
# epoch:   1, Train Loss: 0.0391, Train Acc: 0.8786, Current val_accuracy: 0.8036, Current test_accuracy: 0.8661
# epoch:   2, Train Loss: 0.0389, Train Acc: 0.8857, Current val_accuracy: 0.8348, Current test_accuracy: 0.8705
# epoch:   3, Train Loss: 0.0388, Train Acc: 0.9000, Current val_accuracy: 0.8348, Current test_accuracy: 0.8661
# epoch:   4, Train Loss: 0.0385, Train Acc: 0.9000, Current val_accuracy: 0.8393, Current test_accuracy: 0.8616
# epoch:   5, Train Loss: 0.0383, Train Acc: 0.9000, Current val_accuracy: 0.8393, Current test_accuracy: 0.8661
# epoch:   6, Train Loss: 0.0377, Train Acc: 0.9000, Current val_accuracy: 0.8259, Current test_accuracy: 0.8705
# epoch:   7, Train Loss: 0.0384, Train Acc: 0.9000, Current val_accuracy: 0.8348, Current test_accuracy: 0.8661
# epoch:   8, Train Loss: 0.0385, Train Acc: 0.9000, Current val_accuracy: 0.8348, Current test_accuracy: 0.8616
# epoch:   9, Train Loss: 0.0374, Train Acc: 0.9000, Current val_accuracy: 0.8304, Current test_accuracy: 0.8616
# epoch:  10, Train Loss: 0.0379, Train Acc: 0.9000, Current val_accuracy: 0.8304, Current test_accuracy: 0.8705
# epoch:  11, Train Loss: 0.0379, Train Acc: 0.9000, Current val_accuracy: 0.8304, Current test_accuracy: 0.8705
# epoch:  12, Train Loss: 0.0383, Train Acc: 0.9000, Current val_accuracy: 0.8304, Current test_accuracy: 0.8705
# epoch:  13, Train Loss: 0.0380, Train Acc: 0.9000, Current val_accuracy: 0.8259, Current test_accuracy: 0.8661
# epoch:  14, Train Loss: 0.0382, Train Acc: 0.9000, Current val_accuracy: 0.8259, Current test_accuracy: 0.8750
# The 8 iteration completed.
#
# Validation acc before training: 0.3348214285714286
# Test acc before training: 0.44642857142857145
# epoch:   0, Train Loss: 0.1052, Train Acc: 0.6357, Current val_accuracy: 0.8348, Current test_accuracy: 0.8705
# epoch:   1, Train Loss: 0.0481, Train Acc: 0.8643, Current val_accuracy: 0.8304, Current test_accuracy: 0.8393
# epoch:   2, Train Loss: 0.0473, Train Acc: 0.8643, Current val_accuracy: 0.8304, Current test_accuracy: 0.8393
# epoch:   3, Train Loss: 0.0466, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8214
# epoch:   4, Train Loss: 0.0469, Train Acc: 0.8643, Current val_accuracy: 0.8393, Current test_accuracy: 0.8393
# epoch:   5, Train Loss: 0.0471, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8348
# epoch:   6, Train Loss: 0.0468, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8304
# epoch:   7, Train Loss: 0.0472, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8348
# epoch:   8, Train Loss: 0.0466, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8348
# epoch:   9, Train Loss: 0.0469, Train Acc: 0.8643, Current val_accuracy: 0.8304, Current test_accuracy: 0.8304
# epoch:  10, Train Loss: 0.0467, Train Acc: 0.8643, Current val_accuracy: 0.8304, Current test_accuracy: 0.8304
# epoch:  11, Train Loss: 0.0472, Train Acc: 0.8643, Current val_accuracy: 0.8393, Current test_accuracy: 0.8259
# epoch:  12, Train Loss: 0.0464, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8304
# epoch:  13, Train Loss: 0.0467, Train Acc: 0.8643, Current val_accuracy: 0.8304, Current test_accuracy: 0.8393
# epoch:  14, Train Loss: 0.0472, Train Acc: 0.8643, Current val_accuracy: 0.8348, Current test_accuracy: 0.8348
# The 9 iteration completed.
#
# Validation acc before training: 0.5714285714285714
# Test acc before training: 0.5044642857142857
# epoch:   0, Train Loss: 0.1461, Train Acc: 0.7000, Current val_accuracy: 0.6429, Current test_accuracy: 0.7991
# epoch:   1, Train Loss: 0.0805, Train Acc: 0.7643, Current val_accuracy: 0.5982, Current test_accuracy: 0.8705
# epoch:   2, Train Loss: 0.0500, Train Acc: 0.8143, Current val_accuracy: 0.7098, Current test_accuracy: 0.9018
# epoch:   3, Train Loss: 0.0446, Train Acc: 0.8643, Current val_accuracy: 0.7991, Current test_accuracy: 0.9018
# epoch:   4, Train Loss: 0.0410, Train Acc: 0.9143, Current val_accuracy: 0.8036, Current test_accuracy: 0.8973
# epoch:   5, Train Loss: 0.0403, Train Acc: 0.9071, Current val_accuracy: 0.8036, Current test_accuracy: 0.8661
# epoch:   6, Train Loss: 0.0404, Train Acc: 0.9000, Current val_accuracy: 0.8616, Current test_accuracy: 0.9286
# epoch:   7, Train Loss: 0.0393, Train Acc: 0.9071, Current val_accuracy: 0.8705, Current test_accuracy: 0.9286
# epoch:   8, Train Loss: 0.0395, Train Acc: 0.9071, Current val_accuracy: 0.8705, Current test_accuracy: 0.9330
# epoch:   9, Train Loss: 0.0396, Train Acc: 0.9071, Current val_accuracy: 0.8571, Current test_accuracy: 0.9286
# epoch:  10, Train Loss: 0.0394, Train Acc: 0.9071, Current val_accuracy: 0.8661, Current test_accuracy: 0.9330
# epoch:  11, Train Loss: 0.0391, Train Acc: 0.9071, Current val_accuracy: 0.8616, Current test_accuracy: 0.9330
# epoch:  12, Train Loss: 0.0390, Train Acc: 0.9071, Current val_accuracy: 0.8616, Current test_accuracy: 0.9330
# epoch:  13, Train Loss: 0.0397, Train Acc: 0.9071, Current val_accuracy: 0.8661, Current test_accuracy: 0.9330
# epoch:  14, Train Loss: 0.0392, Train Acc: 0.9071, Current val_accuracy: 0.8616, Current test_accuracy: 0.9330
# The 10 iteration completed.
#
# Test accuracy for 10 runs are : [0.84375, 0.9330357142857143, 0.7008928571428572, 0.8928571428571428, 0.5982142857142857, 0.9375, 0.96875, 0.8616071428571428, 0.8392857142857143, 0.9285714285714286]
# Loading dataset_template_2.json -> saved_datasets/group1/dataset_size50_Nodor4_NOR15_voltage.pkl completed
# Total number of train samples is : 140
# Total number of validation samples is : 30
# Total number of test samples is : 30
# dimx = 15, dimy = 100, n_classes = 4
# Using batch size: 16
# Validation acc before training: 0.13392857142857142
# Test acc before training: 0.26785714285714285
# epoch:   0, Train Loss: 0.1087, Train Acc: 0.7571, Current val_accuracy: 0.8348, Current test_accuracy: 0.7679
# epoch:   1, Train Loss: 0.0391, Train Acc: 0.8714, Current val_accuracy: 0.9688, Current test_accuracy: 0.8304
# epoch:   2, Train Loss: 0.0363, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:   3, Train Loss: 0.0360, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8304
# epoch:   4, Train Loss: 0.0367, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.8438
# epoch:   5, Train Loss: 0.0366, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.8304
# epoch:   6, Train Loss: 0.0357, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.8304
# epoch:   7, Train Loss: 0.0366, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.8304
# epoch:   8, Train Loss: 0.0366, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.8304
# epoch:   9, Train Loss: 0.0358, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:  10, Train Loss: 0.0367, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8259
# epoch:  11, Train Loss: 0.0367, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:  12, Train Loss: 0.0366, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8348
# epoch:  13, Train Loss: 0.0363, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8438
# epoch:  14, Train Loss: 0.0362, Train Acc: 0.8929, Current val_accuracy: 0.9688, Current test_accuracy: 0.8393
# The 1 iteration completed.
#
# Validation acc before training: 0.53125
# Test acc before training: 0.4330357142857143
# epoch:   0, Train Loss: 0.3323, Train Acc: 0.6071, Current val_accuracy: 0.7009, Current test_accuracy: 0.7634
# epoch:   1, Train Loss: 0.0517, Train Acc: 0.8500, Current val_accuracy: 0.8661, Current test_accuracy: 0.8750
# epoch:   2, Train Loss: 0.0335, Train Acc: 0.9429, Current val_accuracy: 0.9375, Current test_accuracy: 0.8661
# epoch:   3, Train Loss: 0.0292, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.8571
# epoch:   4, Train Loss: 0.0284, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.8661
# epoch:   5, Train Loss: 0.0282, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.8616
# epoch:   6, Train Loss: 0.0285, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.8616
# epoch:   7, Train Loss: 0.0285, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.8705
# epoch:   8, Train Loss: 0.0286, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.8616
# epoch:   9, Train Loss: 0.0289, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.8750
# epoch:  10, Train Loss: 0.0285, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.8661
# epoch:  11, Train Loss: 0.0286, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.8705
# epoch:  12, Train Loss: 0.0281, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.8661
# epoch:  13, Train Loss: 0.0285, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.8705
# epoch:  14, Train Loss: 0.0285, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.8661
# The 2 iteration completed.
#
# Validation acc before training: 0.4598214285714286
# Test acc before training: 0.375
# epoch:   0, Train Loss: 0.1293, Train Acc: 0.6857, Current val_accuracy: 0.7991, Current test_accuracy: 0.7902
# epoch:   1, Train Loss: 0.0502, Train Acc: 0.8571, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0328, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0323, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0329, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0328, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0328, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0335, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0325, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0332, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0327, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0326, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0327, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0329, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0328, Train Acc: 0.9786, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 3 iteration completed.
#
# Validation acc before training: 0.5044642857142857
# Test acc before training: 0.5
# epoch:   0, Train Loss: 0.0426, Train Acc: 0.8643, Current val_accuracy: 0.9330, Current test_accuracy: 0.8661
# epoch:   1, Train Loss: 0.0260, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:   2, Train Loss: 0.0259, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9643
# epoch:   3, Train Loss: 0.0255, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:   4, Train Loss: 0.0264, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:   5, Train Loss: 0.0255, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9688
# epoch:   6, Train Loss: 0.0253, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:   7, Train Loss: 0.0255, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   8, Train Loss: 0.0263, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0261, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9643
# epoch:  10, Train Loss: 0.0255, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:  11, Train Loss: 0.0253, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0259, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:  13, Train Loss: 0.0260, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9688
# epoch:  14, Train Loss: 0.0259, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# The 4 iteration completed.
#
# Validation acc before training: 0.4017857142857143
# Test acc before training: 0.5714285714285714
# epoch:   0, Train Loss: 0.1205, Train Acc: 0.7571, Current val_accuracy: 0.8929, Current test_accuracy: 0.9062
# epoch:   1, Train Loss: 0.0327, Train Acc: 0.9571, Current val_accuracy: 0.8929, Current test_accuracy: 0.9062
# epoch:   2, Train Loss: 0.0325, Train Acc: 0.9500, Current val_accuracy: 0.8973, Current test_accuracy: 0.9062
# epoch:   3, Train Loss: 0.0323, Train Acc: 0.9500, Current val_accuracy: 0.9018, Current test_accuracy: 0.9018
# epoch:   4, Train Loss: 0.0324, Train Acc: 0.9500, Current val_accuracy: 0.8973, Current test_accuracy: 0.8973
# epoch:   5, Train Loss: 0.0327, Train Acc: 0.9500, Current val_accuracy: 0.9018, Current test_accuracy: 0.8929
# epoch:   6, Train Loss: 0.0329, Train Acc: 0.9500, Current val_accuracy: 0.9018, Current test_accuracy: 0.8973
# epoch:   7, Train Loss: 0.0329, Train Acc: 0.9500, Current val_accuracy: 0.8973, Current test_accuracy: 0.9062
# epoch:   8, Train Loss: 0.0326, Train Acc: 0.9500, Current val_accuracy: 0.9062, Current test_accuracy: 0.8973
# epoch:   9, Train Loss: 0.0328, Train Acc: 0.9500, Current val_accuracy: 0.8973, Current test_accuracy: 0.9062
# epoch:  10, Train Loss: 0.0326, Train Acc: 0.9500, Current val_accuracy: 0.8973, Current test_accuracy: 0.9018
# epoch:  11, Train Loss: 0.0328, Train Acc: 0.9500, Current val_accuracy: 0.9018, Current test_accuracy: 0.9018
# epoch:  12, Train Loss: 0.0326, Train Acc: 0.9500, Current val_accuracy: 0.8929, Current test_accuracy: 0.9018
# epoch:  13, Train Loss: 0.0328, Train Acc: 0.9500, Current val_accuracy: 0.9062, Current test_accuracy: 0.9018
# epoch:  14, Train Loss: 0.0330, Train Acc: 0.9500, Current val_accuracy: 0.9062, Current test_accuracy: 0.8929
# The 5 iteration completed.
#
# Validation acc before training: 0.6785714285714286
# Test acc before training: 0.6696428571428572
# epoch:   0, Train Loss: 0.1218, Train Acc: 0.6857, Current val_accuracy: 0.9018, Current test_accuracy: 0.9286
# epoch:   1, Train Loss: 0.0282, Train Acc: 0.9143, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0268, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0267, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0272, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0268, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0278, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0270, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0268, Train Acc: 0.9357, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0267, Train Acc: 0.9357, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0266, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0268, Train Acc: 0.9357, Current val_accuracy: 0.9643, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0266, Train Acc: 0.9357, Current val_accuracy: 0.9688, Current test_accuracy: 1.0000
# ...
# dimx = 15, dimy = 100, n_classes = 4
# Using batch size: 16
# Validation acc before training: 0.4642857142857143
# Test acc before training: 0.5758928571428572
# epoch:   0, Train Loss: 0.0808, Train Acc: 0.8286, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   1, Train Loss: 0.0205, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0211, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0209, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0207, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0208, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0203, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0209, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0209, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0207, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0207, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0210, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0205, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0207, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0209, Train Acc: 0.9857, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 1 iteration completed.
#
# Validation acc before training: 0.3035714285714286
# Test acc before training: 0.5
# epoch:   0, Train Loss: 0.1181, Train Acc: 0.6786, Current val_accuracy: 0.7054, Current test_accuracy: 0.5982
# epoch:   1, Train Loss: 0.0778, Train Acc: 0.7929, Current val_accuracy: 0.7991, Current test_accuracy: 0.6920
# epoch:   2, Train Loss: 0.0484, Train Acc: 0.8786, Current val_accuracy: 0.8259, Current test_accuracy: 0.7679
# epoch:   3, Train Loss: 0.0364, Train Acc: 0.9643, Current val_accuracy: 0.9018, Current test_accuracy: 0.9375
# epoch:   4, Train Loss: 0.0357, Train Acc: 0.9714, Current val_accuracy: 0.9018, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0343, Train Acc: 0.9714, Current val_accuracy: 0.8929, Current test_accuracy: 0.9643
# epoch:   6, Train Loss: 0.0343, Train Acc: 0.9786, Current val_accuracy: 0.9018, Current test_accuracy: 0.9688
# epoch:   7, Train Loss: 0.0351, Train Acc: 0.9786, Current val_accuracy: 0.9018, Current test_accuracy: 0.9688
# epoch:   8, Train Loss: 0.0344, Train Acc: 0.9786, Current val_accuracy: 0.9062, Current test_accuracy: 0.9643
# epoch:   9, Train Loss: 0.0347, Train Acc: 0.9786, Current val_accuracy: 0.8973, Current test_accuracy: 0.9643
# epoch:  10, Train Loss: 0.0340, Train Acc: 0.9786, Current val_accuracy: 0.8929, Current test_accuracy: 0.9688
# epoch:  11, Train Loss: 0.0340, Train Acc: 0.9786, Current val_accuracy: 0.9018, Current test_accuracy: 0.9688
# epoch:  12, Train Loss: 0.0342, Train Acc: 0.9786, Current val_accuracy: 0.8929, Current test_accuracy: 0.9643
# epoch:  13, Train Loss: 0.0340, Train Acc: 0.9786, Current val_accuracy: 0.8973, Current test_accuracy: 0.9643
# epoch:  14, Train Loss: 0.0339, Train Acc: 0.9786, Current val_accuracy: 0.8973, Current test_accuracy: 0.9643
# The 2 iteration completed.
#
# Validation acc before training: 0.19642857142857142
# Test acc before training: 0.3348214285714286
# epoch:   0, Train Loss: 0.0868, Train Acc: 0.8500, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   1, Train Loss: 0.0276, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   2, Train Loss: 0.0272, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   3, Train Loss: 0.0269, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   4, Train Loss: 0.0269, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   5, Train Loss: 0.0272, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   6, Train Loss: 0.0270, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:   7, Train Loss: 0.0275, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   8, Train Loss: 0.0275, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0271, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:  10, Train Loss: 0.0267, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:  11, Train Loss: 0.0271, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0270, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9688
# epoch:  13, Train Loss: 0.0269, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# epoch:  14, Train Loss: 0.0269, Train Acc: 0.9714, Current val_accuracy: 1.0000, Current test_accuracy: 0.9643
# The 3 iteration completed.
#
# Validation acc before training: 0.45535714285714285
# Test acc before training: 0.4732142857142857
# epoch:   0, Train Loss: 0.1707, Train Acc: 0.7286, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   1, Train Loss: 0.0284, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0279, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0278, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0282, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0282, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0284, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0284, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0280, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0283, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0281, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0277, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0282, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0283, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0284, Train Acc: 0.9643, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 4 iteration completed.
#
# Validation acc before training: 0.6026785714285714
# Test acc before training: 0.29464285714285715
# epoch:   0, Train Loss: 0.1889, Train Acc: 0.7357, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   1, Train Loss: 0.0259, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0261, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0265, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0261, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0259, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0267, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0263, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0259, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0265, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0259, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0260, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0265, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0259, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0261, Train Acc: 0.9929, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 5 iteration completed.
#
# Validation acc before training: 0.3705357142857143
# Test acc before training: 0.6026785714285714
# epoch:   0, Train Loss: 0.0482, Train Acc: 0.8929, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   1, Train Loss: 0.0265, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:   2, Train Loss: 0.0265, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:   3, Train Loss: 0.0266, Train Acc: 0.9714, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# epoch:   4, Train Loss: 0.0263, Train Acc: 0.9714, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# epoch:   5, Train Loss: 0.0265, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:   6, Train Loss: 0.0265, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:   7, Train Loss: 0.0262, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:   8, Train Loss: 0.0267, Train Acc: 0.9714, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0263, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9643
# epoch:  10, Train Loss: 0.0262, Train Acc: 0.9714, Current val_accuracy: 0.9643, Current test_accuracy: 0.9688
# epoch:  11, Train Loss: 0.0266, Train Acc: 0.9714, Current val_accuracy: 0.9643, Current test_accuracy: 0.9643
# epoch:  12, Train Loss: 0.0267, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:  13, Train Loss: 0.0260, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# epoch:  14, Train Loss: 0.0265, Train Acc: 0.9714, Current val_accuracy: 0.9688, Current test_accuracy: 0.9688
# The 6 iteration completed.
#
# Validation acc before training: 0.4598214285714286
# Test acc before training: 0.4955357142857143
# epoch:   0, Train Loss: 0.0400, Train Acc: 0.9357, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   1, Train Loss: 0.0234, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0230, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0223, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0226, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0230, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0230, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0232, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0226, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0228, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0230, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0226, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0230, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0226, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0228, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 7 iteration completed.
#
# Validation acc before training: 0.23214285714285715
# Test acc before training: 0.26339285714285715
# epoch:   0, Train Loss: 0.0996, Train Acc: 0.8214, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   1, Train Loss: 0.0240, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   2, Train Loss: 0.0238, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   3, Train Loss: 0.0238, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   4, Train Loss: 0.0241, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   5, Train Loss: 0.0240, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   6, Train Loss: 0.0243, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   7, Train Loss: 0.0244, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   8, Train Loss: 0.0234, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:   9, Train Loss: 0.0236, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  10, Train Loss: 0.0236, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  11, Train Loss: 0.0238, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  12, Train Loss: 0.0240, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  13, Train Loss: 0.0238, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# epoch:  14, Train Loss: 0.0236, Train Acc: 1.0000, Current val_accuracy: 1.0000, Current test_accuracy: 1.0000
# The 8 iteration completed.
#
# Validation acc before training: 0.6339285714285714
# Test acc before training: 0.4375
# epoch:   0, Train Loss: 0.1189, Train Acc: 0.7071, Current val_accuracy: 0.9018, Current test_accuracy: 0.9062
# epoch:   1, Train Loss: 0.0277, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9643
# epoch:   2, Train Loss: 0.0263, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   3, Train Loss: 0.0266, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   4, Train Loss: 0.0270, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9643
# epoch:   5, Train Loss: 0.0277, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   6, Train Loss: 0.0264, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9688
# epoch:   7, Train Loss: 0.0269, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9643
# epoch:   8, Train Loss: 0.0271, Train Acc: 0.9857, Current val_accuracy: 0.9375, Current test_accuracy: 0.9688
# epoch:   9, Train Loss: 0.0268, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:  10, Train Loss: 0.0273, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9643
# epoch:  11, Train Loss: 0.0268, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
# epoch:  12, Train Loss: 0.0270, Train Acc: 0.9857, Current val_accuracy: 0.9286, Current test_accuracy: 0.9643
# epoch:  13, Train Loss: 0.0269, Train Acc: 0.9857, Current val_accuracy: 0.9330, Current test_accuracy: 0.9688
